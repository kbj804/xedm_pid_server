# %%
import pycaret
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = './csv_files/label_00005681335550.csv'
train = pd.read_csv(data_path)
train
# Out:
#       wavelength         x         y         z
# 0         0.0000  1.921875 -4.043945  2.082031
# 1         0.0005  2.402344 -3.843750  1.641602
# 2         0.0010  2.682617 -3.723633  1.000977
# 3         0.0015  3.123047 -3.483398  0.360352
# 4         0.0020  3.403320 -2.842773 -0.480469
# ...          ...       ...       ...       ...
# 1995      0.9975 -2.082031 -1.641602  3.643555
# 1996      0.9980 -1.361328 -2.242188  3.483398
# 1997      0.9985 -0.680664 -2.722656  3.323242
# 1998      0.9990  0.040039 -3.243164  3.123047
# 1999      0.9995  0.880859 -3.563477  2.682617
#
# [2000 rows x 4 columns]

# %%
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train["wavelength"], "mo-")
axs[1].plot(train["x"], train["wavelength"], "mo-")
axs[2].plot(train["y"], train["wavelength"], "mo-")
axs[3].plot(train["z"], train["wavelength"], "mo-")

# %%
data_path = './csv_files/label_00006320620311.csv'
train2 = pd.read_csv(data_path)
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train2["wavelength"], "mo-")
axs[1].plot(train2["x"], "mo-")
axs[2].plot(train2["y"], "mo-")
axs[3].plot(train2["z"], "mo-")

# %%
data_path = './csv_files/label_00006360996590.csv'
train = pd.read_csv(data_path)
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train["wavelength"], "mo-")
axs[1].plot(train["x"], "mo-")
axs[2].plot(train["y"], "mo-")
axs[3].plot(train["z"], "mo-")

# %%
data_path = './csv_files/label_00009213334351.csv'
train = pd.read_csv(data_path)
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train["wavelength"], "mo-")
axs[1].plot(train["x"], "mo-")
axs[2].plot(train["y"], "mo-")
axs[3].plot(train["z"], "mo-")

# %%
data_path = './csv_files/label_00012641017965.csv'
train = pd.read_csv(data_path)
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train["wavelength"], "mo-")
axs[1].plot(train["x"], "mo-")
axs[2].plot(train["y"], "mo-")
axs[3].plot(train["z"], "mo-")

# %%
data_path = './csv_files/label_00013801234875.csv'
train = pd.read_csv(data_path)
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train["wavelength"], "mo-")
axs[1].plot(train["x"], "mo-")
axs[2].plot(train["y"], "mo-")
axs[3].plot(train["z"], "mo-")

# %%
data_path = './csv_files/label_03800193044780.csv'
train = pd.read_csv(data_path)
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train["wavelength"], "mo-")
axs[1].plot(train["x"], "mo-")
axs[1].set_ylim(-20,20)
axs[2].plot(train["y"], "mo-")
axs[2].set_ylim(-20,20)
axs[3].plot(train["z"], "mo-")
axs[3].set_ylim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
data_path = './csv_files/label_03812298628625.csv'
train = pd.read_csv(data_path)
fig, axs = plt.subplots(nrows=4, figsize=(18, 15), constrained_layout=True)
axs[0].plot(train["wavelength"], "mo-")
axs[1].plot(train["x"], "mo-")
axs[1].set_ylim(-20,20)
axs[1].plot(train["y"])
axs[2].set_ylim(-20,20)
axs[3].plot(train["z"], "mo-")
axs[3].set_ylim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
if train[train['x'] > 3].values.tolist():
# Out:
# s

# %%
import os
file_list = os.listdir('./csv_files')
len(file_list)
# Out:
# 8744

# %%
def show_data(data_path):
    train = pd.read_csv(f'./csv_files/{data_path}')
    if train[train['x'] > 20].values.tolist():
        return 1
    else:
        return 0

trash_list = []

for file in file_list:
    flag = show_data(file)
    if flag == 1:
        trash_list.append(file)
    else:
        pass

# %%
len(trash_list)
# Out:
# 834

# %%
test = pd.read_csv('./submission.csv')
test
# Out:
#         ID             rand_filename  anomaly_score
# 0        1  label_27921666244421.csv            0.5
# 1        2  label_67523526149398.csv            0.5
# 2        3  label_87360334431517.csv            0.5
# 3        4  label_74646340700426.csv            0.5
# 4        5  label_75222372878129.csv            0.5
# ...    ...                       ...            ...
# 8739  8740  label_15734372056046.csv            0.5
# 8740  8741  label_41274568351349.csv            0.5
# 8741  8742  label_49327827157734.csv            0.5
# 8742  8743  label_80148122275074.csv            0.5
# 8743  8744  label_45580710955127.csv            0.5
#
# [8744 rows x 3 columns]

# %%
def change(f_name):
    if f_name in trash_list:
        return 1
    else:
        return 0

test['anomaly_score'] = test['rand_filename'].apply(lambda x : change(x))

# %%
test[test['anomaly_score']== 1 ]
# Out:
#         ID             rand_filename  anomaly_score
# 15      16  label_49899404361789.csv              1
# 20      21  label_18370247514580.csv              1
# 28      29  label_32071595980767.csv              1
# 51      52  label_36589326133793.csv              1
# 57      58  label_86824548950503.csv              1
# ...    ...                       ...            ...
# 8682  8683  label_54380642227391.csv              1
# 8690  8691  label_69417706158967.csv              1
# 8698  8699  label_54638211173726.csv              1
# 8706  8707  label_70015164299884.csv              1
# 8734  8735  label_60194958761564.csv              1
#
# [834 rows x 3 columns]

# %%
test.to_csv('sub.csv', index=False)
